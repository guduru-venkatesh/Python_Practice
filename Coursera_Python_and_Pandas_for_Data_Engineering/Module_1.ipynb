# %% [markdown]
# <a href="https://colab.research.google.com/github/guduru-venkatesh/Python_Practice/blob/main/Coursera_Python_and_Pandas_for_Data_Engineering/Module_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data ={'Name':['Venkat','Alekhya'],'Age':[30,25]}

print(data)
# Out:
# {'Name': ['Venkat', 'Alekhya'], 'Age': [30, 25]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name  Age
# 0   Venkat   30
# 1  Alekhya   25

# %%
for index, row in df.iterrows():
    print(row['Name'], row['Age'], index);
# Out:
# Venkat 30 0
# Alekhya 25 1

# %%
df.to_csv('data.csv')

# %%
df2 = pd.read_csv('data.csv')

# %%
# prompt: show files in current directpory
# !pwd
# !ls
# Out:
# /content
# data.csv  sample_data

# %%
import pickle
pickle.dump(df, open('df.pkl', 'wb'))
df3 = pickle.load(open('df.pkl', 'rb'))

# %%
df3
# Out:
#       Name  Age
# 0   Venkat   30
# 1  Alekhya   25
